# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: A prediction about which customers free-tier customers will become paying customers.

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer: Age, gender, location, profesttion, days since last log in, and activity score.

# %% [markdown]
# #### 3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: The usage data is from January 2015 to April 2015.

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: More active users are more likely to convert to paying customers.

# %% [markdown]
# ## Let's test your knowledge of pandas

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %% [markdown]
# #### 1. Load the dataset from assets/admissions.csv

# %%
data = pd.read_csv("/anaconda/jupyter-notebooks/DAT-BOS-15/projects/unit-projects/project-1/assets/admissions.csv")
hooli_frame = pd.DataFrame(data)
hooli_frame
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %% [markdown]
# #### 2. Uh oh, you weren't given a data dictionary! Try to determine what 0/1 refer to in the admit column. Explain your logic. (You may assume that higher GPA's and GRE scores are better)

# %%
# It seems likely that 1 would correspond to applicants that were admitted
# and 0 would correspond to applicants that were rejected.
# If you look at the differences, the Admit = 0 entries tend to have lower scores in GRE
# and GPA than do the Admit = 1 entries.

# %%
hooli_frame_admit0 = hooli_frame[hooli_frame["admit"]==0]
hooli_frame_admit0_prestige = hooli_frame.loc[(hooli_frame["admit"]==0) & (hooli_frame["prestige"]>=3)]
print "Admit == 0"
print "GRE Median: {}".format(hooli_frame_admit0['gre'].median())
print "GRE Mean: {}".format(hooli_frame_admit0['gre'].mean())
print "GPA Median: {}".format(hooli_frame_admit0['gpa'].median())
print "GPA Mean: {}".format(hooli_frame_admit0['gpa'].mean())
print "Prestige Median: {}".format(hooli_frame_admit0['prestige'].median())
print "Prestige Mean: {}".format(hooli_frame_admit0['prestige'].mean())
print "\n"
# display(hooli_frame_admit0.describe().round({'admit':0,'gre':1,'gpa':2,'prestige':1}))
print "Admit == 0 AND Prestige >= 3 or more"
print "GRE Median: {}".format(hooli_frame_admit0_prestige['gre'].median())
print "GRE Mean: {}".format(hooli_frame_admit0_prestige['gre'].mean())
print "GPA Median: {}".format(hooli_frame_admit0_prestige['gpa'].median())
print "GPA Mean: {}".format(hooli_frame_admit0_prestige['gpa'].mean())
print "Prestige Median: {}".format(hooli_frame_admit0_prestige['prestige'].median())
print "Prestige Mean: {}".format(hooli_frame_admit0_prestige['prestige'].mean())
# display(hooli_frame_admit0_prestige.describe().round({'admit':0,'gre':1,'gpa':2,'prestige':1}))
# Out:
# Admit == 0
# GRE Median: 580.0
# GRE Mean: 573.579335793
# GPA Median: 3.34
# GPA Mean: 3.34540441176
# Prestige Median: 3.0
# Prestige Mean: 2.64102564103
#
#
# Admit == 0 AND Prestige >= 3 or more
# GRE Median: 560.0
# GRE Mean: 562.567567568
# GPA Median: 3.35
# GPA Mean: 3.36108108108
# Prestige Median: 3.0
# Prestige Mean: 3.37162162162

# %%
hooli_frame_admit1 = hooli_frame[hooli_frame["admit"]==1]
hooli_frame_admit1_prestige = hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]>=3)]
print "Admit == 1"
print "GRE Median: {}".format(hooli_frame_admit1['gre'].median())
print "GRE Mean: {}".format(hooli_frame_admit1['gre'].mean())
print "GPA Median: {}".format(hooli_frame_admit1['gpa'].median())
print "GPA Mean: {}".format(hooli_frame_admit1['gpa'].mean())
print "Prestige Median: {}".format(hooli_frame_admit1['prestige'].median())
print "Prestige Mean: {}".format(hooli_frame_admit1['prestige'].mean())
print "\n"
#display(hooli_frame_admit1.describe().round({'admit':0,'gre':1,'gpa':2,'prestige':1}))
print "Admit == 1 AND Prestige >= 3 or more"
print "GRE Median: {}".format(hooli_frame_admit1_prestige['gre'].median())
print "GRE Mean: {}".format(hooli_frame_admit1_prestige['gre'].mean())
print "GPA Median: {}".format(hooli_frame_admit1_prestige['gpa'].median())
print "GPA Mean: {}".format(hooli_frame_admit1_prestige['gpa'].mean())
print "Prestige Median: {}".format(hooli_frame_admit1_prestige['prestige'].median())
print "Prestige Mean: {}".format(hooli_frame_admit1_prestige['prestige'].mean())
print "\n"
#display(hooli_frame_admit1_prestige.describe().round({'admit':0,'gre':1,'gpa':2,'prestige':1}))
print "Breakdown of median scores by Prestige Score"
print "\n"
print "Prestige 1: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==1)].median())
print "\n"
print "Prestige 2: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==2)].median())
print "\n"
print "Prestige 3: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==3)].median())
print "\n"
print "Prestige 4: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==4)].median())
print "\n"
print "Breakdown of mean scores by Prestige Score"
print "\n"
print "Prestige 1: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==1)].mean())
print "\n"
print "Prestige 2: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==2)].mean())
print "\n"
print "Prestige 3: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==3)].mean())
print "\n"
print "Prestige 4: \n{}".format(hooli_frame.loc[(hooli_frame["admit"]==1) & (hooli_frame["prestige"]==4)].mean())
# Out:
# Admit == 1
# GRE Median: 620.0
# GRE Mean: 618.897637795
# GPA Median: 3.545
# GPA Mean: 3.48920634921
# Prestige Median: 2.0
# Prestige Mean: 2.15079365079
#
#
# Admit == 1 AND Prestige >= 3 or more
# GRE Median: 620.0
# GRE Mean: 612.5
# GPA Median: 3.6
# GPA Mean: 3.50675
# Prestige Median: 3.0
# Prestige Mean: 3.3
#
#
# Breakdown of median scores by Prestige Score
#
#
# Prestige 1:
# admit         1.00
# gre         620.00
# gpa           3.61
# prestige      1.00
# dtype: float64
#
#
# Prestige 2:
# admit         1.00
# gre         620.00
# gpa           3.45
# prestige      2.00
# dtype: float64
#
#
# Prestige 3:
# admit         1.00
# gre         620.00
# gpa           3.62
# prestige      3.00
# dtype: float64
#
#
# Prestige 4:
# admit         1.000
# gre         610.000
# gpa           3.535
# prestige      4.000
# dtype: float64
#
#
# Breakdown of mean scores by Prestige Score
#
#
# Prestige 1:
# admit         1.000000
# gre         636.363636
# gpa           3.544242
# ...

# %% [markdown]
# #### 3. What are the mean/median GPA and GRE scores for those admitted?

# %%
# Admit == 1
# GRE Median: 620.0
# GRE Mean: 618.897637795
# GPA Median: 3.545
# GPA Mean: 3.48920634921
# Prestige Median: 2.0
# Prestige Mean: 2.15079365079

# %% [markdown]
# #### 4. Which schools do you think are more prestigous, those with a prestige score of 1 or 4? Explain your logic.

# %%
# In both cases, rejected and admitted, gre and GPA means/medians are higher when the
# prestige is 1 vs. when the prestige is 4. You might assume that it requires better
# scores to attend more prestigious universities.

# %% [markdown]
# #### 5. Create a data dictionary for this dataset.

# %%
# Admit: 1 - Admitted, 0 - Rejected
# Prestige: 1 - Most Prestigious University, 4 - Least Prestigious University
# GPA: Grade Point Average - Score from 0 to 4.
# GRE: Test Score - 0 to 800
